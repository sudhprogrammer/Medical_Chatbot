# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# comm                    0.2.3
# debugpy                 1.8.17
# decorator               5.2.1
# executing               2.2.1
# ipykernel               7.1.0
# ipython                 9.7.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.9.1
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# packaging               25.0
# parso                   0.8.5
# pexpect                 4.9.0
# pip                     25.3
# platformdirs            4.5.0
# prompt_toolkit          3.0.52
# psutil                  7.1.3
# ptyprocess              0.7.0
# pure_eval               0.2.3
# Pygments                2.19.2
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.5.2
# traitlets               5.14.3
# wcwidth                 0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
pwd
# Out:
# '/home/Project25-26/Medical_Chatbot/research'

# %%
import os
os.chdir("../")

# %%
pwd
# Out:
# '/home/Project25-26/Medical_Chatbot'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
def load_pdf_files(data):
    loader = DirectoryLoader(
        data,
        glob="*.pdf",
        loader_cls=PyPDFLoader
    )
    documents = loader.load()
    return documents

# %%
extracted_data=load_pdf_files(data)
